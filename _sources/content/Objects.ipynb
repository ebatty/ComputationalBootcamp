# %% [markdown]
# <a href="https://colab.research.google.com/github/ebatty/ComputationalBootcamp/blob/master/content/Objects.ipynb" target="_blank"><img alt="Open In Colab" src="https://colab.research.google.com/assets/colab-badge.svg"/></a>

# %% [markdown]
# # Objects

# %% [markdown]
#  Video

# %%
#@markdown Video
from IPython.display import YouTubeVideo
video = YouTubeVideo(id="m7k8_i4BqCc", width=730, height=410, fs=1)
print("Video available at https://youtube.com/watch?v=" + video.id)
video
# Out:
# Video available at https://youtube.com/watch?v=m7k8_i4BqCc
